# %% [markdown]
# Linear Clustering Plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn.cluster import KMeans

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn


from sklearn.cluster import DBSCAN
from collections import Counter

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split

import graphviz
import io  
from scipy import misc

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import sklearn
from sklearn.datasets import make_blobs

from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import scale

import seaborn as sb
from pylab import rcParams

from sklearn.cluster import DBSCAN

from collections import Counter

import sklearn.metrics as sm
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import sklearn
from sklearn.datasets import make_blobs

from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import scale

import sklearn.metrics as sm
from sklearn import datasets
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler

# %%
irisData = pd.read_csv('army.csv')
irisData
# Out:
#       ID          Country Name      2013      2014      2015      2016  \
# 0      1           Afghanistan    330650    308800    319400    323000
# 1      2                Angola    117000    117000    117000    117000
# 2      3               Albania      8500      8500      8500      8500
# 3      4            Arab World   2866760   2881760   2881560   2781410
# 4      5  United Arab Emirates     63000     63000     63000     63000
# ..   ...                   ...       ...       ...       ...       ...
# 207  208                 World  27206623  27309630  27437280  27542350
# 208  209                 Yemen    137900     20000     20000     20000
# 209  210          South Africa     77150     82250     82150     81400
# 210  211                Zambia     16500     16500     16500     16500
# 211  212              Zimbabwe     50800     50800     50800     50800
#
#          2017
# 0      323000
# 1      117000
# 2        9000
# 3     2737000
# 4       63000
# ..        ...
# ...

# %%
plt.rcParams["figure.figsize"] = (15,15)
plt.scatter(irisData['2017'],irisData['Country Name'])

# %%
km = KMeans(n_clusters = 3)
y_predicted = km.fit_predict(irisData[['2017','ID']])

# %%
irisData['cluster'] = y_predicted

# %%
km.cluster_centers_

df1 = irisData[irisData.cluster == 0]
df2 = irisData[irisData.cluster == 1]
df3 = irisData[irisData.cluster == 2]

plt.scatter(df1['2017'],df1['ID'], color = 'yellow')
plt.scatter(df2['2017'],df2['ID'], color = 'red')
plt.scatter(df3['2017'],df3['ID'], color = 'skyblue')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1], color = 'black', marker = '*', label = 'centroid')
